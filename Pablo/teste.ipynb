# %%
import os
import pandas as pd

# %%
df = pd.read_csv("input/scimagojr2020.csv", low_memory = False, sep = ";")

# %%
df.head(2)
# Out:
#    Rank  Sourceid                               Title     Type  \
# 0     1     28773  Ca-A Cancer Journal for Clinicians  journal
# 1     2     19434    MMWR Recommendations and Reports  journal
#
#                  Issn     SJR SJR Best Quartile  H index  Total Docs. (2020)  \
# 0  15424863, 00079235  62,937                Q1      168                  47
# 1  10575987, 15458601  40,949                Q1      143                  10
#
#    Total Docs. (3years)  Total Refs.  Total Cites (3years)  \
# 0                   119         3452                 15499
# 1                     9         1292                   492
#
#    Citable Docs. (3years) Cites / Doc. (2years) Ref. / Doc.        Country  \
# 0                      80                126,34       73,45  United States
# 1                       9                 50,00      129,20  United States
#
#              Region                                         Publisher  \
# ...

# %%
df.dropna(axis=1, inplace=False)

# %%
df2 = pd.read_csv("input/jcs_2020.csv", low_memory = False, sep = ";")

# %%
df2.dropna(axis=1, inplace=False)
# Out:
#         Rank                             Full Journal Title Total Cites  \
# 0          1             CA-A CANCER JOURNAL FOR CLINICIANS      55,868
# 1          2          NATURE REVIEWS MOLECULAR CELL BIOLOGY      58,477
# 2          3                NEW ENGLAND JOURNAL OF MEDICINE     464,351
# 3          4                  NATURE REVIEWS DRUG DISCOVERY      41,989
# 4          5                                         LANCET     369,601
# ...      ...                                            ...         ...
# 13005  12982                           Ornithology Research           2
# 13006  12982  Physical and Engineering Sciences in Medicine         184
# 13007  12982                        RSC Medicinal Chemistry         104
# 13008  12982                          Studies in Psychology           9
# 13009  12982                           Syntax and Semantics         697
#
#       Journal Impact Factor  Eigenfactor Score
# 0                   508.702            0.10514
# ...

# %%
df2.rename(columns={'Journal Impact Factor': 'scimago_value'}, inplace = True)

# %%
df2.head(2)
# Out:
#    Rank                     Full Journal Title Total Cites  Unnamed: 3  \
# 0     1     CA-A CANCER JOURNAL FOR CLINICIANS      55,868         NaN
# 1     2  NATURE REVIEWS MOLECULAR CELL BIOLOGY      58,477         NaN
#
#   scimago_value  Eigenfactor Score  Unnamed: 6  Unnamed: 7
# 0       508.702            0.10514         NaN         NaN
# 1        94.444            0.07548         NaN         NaN

# %%
 df_class_2 = read_file_csv(output_file, file_class_2)
# Out:
# ok

# %%
#result = pd.concat([df, df2], axis=0)

# %%
#print(df.shape, df2.shape, result.shape)

# %%
#result.tail(5)
