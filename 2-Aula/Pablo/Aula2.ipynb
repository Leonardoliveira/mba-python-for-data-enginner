# %%
import os
import bibtexparser 
import pandas as pd
import numpy as np

# %%
# parametrsos globais
entrada = "input/"
saida = "output/"

# %%
# Função para criar um lista dos arquivos BibTex existentes no diretório de entrada 
def get_files(dir):
    
    # carregando os arquivos da pasta entrada
    dir_list = os.listdir(dir)
    files_list = []
    
    for file in dir_list:
    
        # validar se o arquivo do diretório possui a extensao .bib
        if '.BIB' not in file.upper():
            continue

        files_list.append(file)
    
    return files_list

# %%
# função para carregar o arquivo em um DF
def read_file(dir, file):
    
    with open(dir + file, encoding = "utf_8" ) as bibtex_file:
        
        bib_database = bibtexparser.load(bibtex_file)
        
    # retornando um DF do arquivo 
    return pd.DataFrame(bib_database.entries)

# %%
# Função para criar um novo DF com as colunas do escopo baseado no DF Geral
def select_col(df_geral):
    
    # criando um lista com as colunas do escopo do projeto
    col_types = [["author"],["title"],["keywords"],["abstract"],["year"],
                 ["type_publication","ENTRYTYPE"],["doi"]]
    
    new_df = pd.DataFrame()

    # interar lista de todos os tipos de colunas
    for col_type in col_types:

        # interar uma lista de um tipo de coluna apenas
        for col in col_type:

            # verificar se um item do tipo existe no DF
            if col in df_geral.columns:
                # se existir criar um nova coluna no new_DF com o rótulo do primeiro item da lista do tipo da coluna
                new_df[col_type[0]] = df_geral[col]
                break
            else:
                # se a coluna não existir então verificar se é a última coluna da lista do tipo
                # isso significa que não existe a coluna no DF, então criar um coluna com o rótulo do primeiro item 
                # com conteúdo em branco
                if col == col_type[-1]:
                    new_df[col_type[0]] = np.nan

    new_df["file"] = file
    
    return new_df

# %%
# Principal
files = get_files(entrada)

## fazer a leitura de todos os arquivos
# criando um DF em branco para armazenar todos os arquivos
df_final = pd.DataFrame()

for file in files:
    
    # carregando dados do arquivo para um DF
    df_geral = read_file(entrada, file)
    
    # criando um novo DF selecionando colunas
    new_df = select_col(df_geral)
    
    # concatendando cada novo DF no DF Final
    df_final = pd.concat([df_final, new_df])

# %%
df_final
# Out:
#                                                 author  \
# 0    El Alaoui, Imane and Gahi, Youssef and Messous...
# 1    Reda, Oumaima and Sassi, Imad and Zellou, Ahme...
# 2                  Emmanuel, Isitor and Stanier, Clare
# 3    Baldassarre, Maria Teresa and Caballero, Ismae...
# 4    Cuzzocrea, Alfredo and Sacc\`{a}, Domenico and...
# ..                                                 ...
# 995                                 Ana Isabel Canhoto
# 996  Daqing Wang and Haoli Xu and Yue Shi and Zhibi...
# 997  R. Priyadarshini and Latha Tamilselvan and T. ...
# 998  Chenhao Tian and Chenghong Feng and Lei Chen a...
# 999  Guoyin Jiang and Xiaodong Feng and Wenping Liu...
#
#                                                  title  \
# 0    Big Data Quality Metrics for Sentiment Analysi...
# 1        Towards a Data Quality Assessment in Big Data
# 2                                    Defining Big Data
# 3    From Big Data to Smart Data: A Data Quality Pe...
# 4                          Big Data: A Research Agenda
# ..                                                 ...
# 995  Leveraging machine learning in the global figh...
# 996  The groundwater potential assessment system ba...
# 997  Semantic Retrieval of Relevant Sources for Lar...
# 998  Impact of water source mixture and population ...
# 999  Clicking position and user posting behavior in...
#
#                                               keywords  \
# 0    Big data, Sentiment analysis, Big data quality...
# 1    Data Quality, Quality Models, Data Quality eva...
# 2    Big Data, Big Data characteristics, Data Quali...
# 3                   Smart Data, Data Quality, Big Data
# 4    OLAP over big data, privacy of big data, big d...
# ..                                                 ...
# 995  Big data, Artificial intelligence, Machine lea...
# 996  Big data, Cloud computing, Remote sensing, Gro...
# 997  Virtual documents (VD), Source document, Hadoo...
# 998  Al residue, Mixed water sources, Big data anal...
# 999  Agent-based modeling, Big data, Online review ...
#
#                                               abstract  year type_publication  \
# 0    In a world increasingly connected, and in whic...  2019    inproceedings
# 1    In recent years, as more and more data sources...  2020    inproceedings
# 2    As Big Data becomes better understood, there i...  2016    inproceedings
# 3    Big Data (BD) solutions are designed to better...  2018    inproceedings
# 4    Recently, a great deal of interest for Big Dat...  2013    inproceedings
# ..                                                 ...   ...              ...
# 995  Financial services organisations facilitate th...  2021          article
# 996  Today’s intelligent system based on cloud comp...  2021          article
# 997  The term big data has come into use in recent ...  2015          article
# 998  This study establishes a new understanding of ...  2020          article
# 999  In online review systems, a participant's leve...  2020          article
#
#                                                doi        file
# 0                          10.1145/3341620.3341629     acm.bib
# 1                          10.1145/3419604.3419803     acm.bib
# 2                          10.1145/3010089.3010090     acm.bib
# 3                          10.1145/3281022.3281026     acm.bib
# 4                          10.1145/2513591.2527071     acm.bib
# ..                                             ...         ...
# 995  https://doi.org/10.1016/j.jbusres.2020.10.012  sdFull.bib
# 996   https://doi.org/10.1016/j.comcom.2021.06.028  sdFull.bib
# 997    https://doi.org/10.1016/j.procs.2015.06.043  sdFull.bib
# 998   https://doi.org/10.1016/j.watres.2020.116335  sdFull.bib
# 999      https://doi.org/10.1016/j.ins.2019.09.053  sdFull.bib
#
# [1350 rows x 8 columns]
